# %% [markdown]
# <a href="https://colab.research.google.com/github/swati-1808/Transforming-EDA-Projects-to-Dashboards/blob/main/The_DataViz_Challenge_Transforming_EDA_Projects_to_Dashboards.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **Project Name - The DataViz Challenge - Transforming EDA Projects to Dashboards**

# %% [markdown]
# # **Tableau Public Link**

# %% [markdown]
# https://public.tableau.com/app/profile/swati.gupta3844/viz/TheDataVizChallenge/HOTELBOOKINGANALYSIS

# %% [markdown]
# # **Project Summary -**

# %% [markdown]
# The goal of this project is to analyze a hotel booking dataset using Python's Pandas, Tableau. The dataset contains information about bookings for both a city hotel and a resort hotel, including details such as booking dates, length of stay, number of guests, and special requests. Develop visualisations and apply statistical techniques if required to test the assumptions . Drawing insights from the research like :- What were you able to learn from the analysis? Did your assumptions turn out to be right? How would your analysis be helpful to the stakeholders?
#
# Begin by addressing the disorder and inconsistency within the dataset. Utilise Jupyter Notebook and Tableau Prep to systematically cleanse the data, rectifying discrepancies, eliminating duplicates, and standardising formats.
#
# This inquiry seeks to leverage Tableau's visual analytics capabilities to uncover and illustrate the shared attributes, disparities, and distinctive patterns inherent by hotel booking analysis dataset, thus elevating the depth and insightfulness of the study.

# %% [markdown]
# # **GitHub Link -**

# %% [markdown]
# https://github.com/swati-1808/Transforming-EDA-Projects-to-Dashboards

# %% [markdown]
# # **Problem Statement**

# %% [markdown]
# Have you ever wondered when the best time of year to book a hotel room is? Or the optimal length of stay in order to get the best daily rate? What if you wanted to predict whether or not a hotel was likely to receive a disproportionately high number of special requests? This hotel booking dataset can help you explore those questions! This data set contains booking information for a city hotel and a resort hotel, and includes information such as when the booking was made, length of stay, the number of adults, children, and/or babies, and the number of available parking spaces, among other things. All personally identifying information has been removed from the data. Explore and analyse the data to discover important factors that govern the bookings.
#
# In the context of hotel data provided how can the utilisation of Tableau facilitate a comprehensive comparative examination between different scenario?

# %% [markdown]
# #### **Define Your Business Objective?**

# %% [markdown]
# The business objective, in the context of analyzing the hotel booking dataset, can vary based on the goals of the organization or individual involved. Here are a few potential business objectives that could guide the analysis:
#
# Optimizing Booking , Customer Segmentation ,Revenue Optimization , Operational Efficiency , etc.

# %% [markdown]
# # ***Let's Begin !***

# %% [markdown]
# ## ***1. Know Your Data***

# %% [markdown]
# ### Import Libraries

# %%
# Import Libraries

import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from datetime import datetime

# %% [markdown]
# ### Dataset Loading

# %%
# Load Dataset
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
# Path to the CSV file
file_path = '/content/drive/MyDrive/Hotel Bookings.csv'

# %%
# Load the CSV file into a Pandas DataFrame
df = pd.read_csv(file_path)

# %% [markdown]
# ### Dataset First View

# %%
# Dataset First Look
df
# Out:
#                hotel  is_canceled  lead_time  arrival_date_year  \
# 0       Resort Hotel            0        342               2015
# 1       Resort Hotel            0        737               2015
# 2       Resort Hotel            0          7               2015
# 3       Resort Hotel            0         13               2015
# 4       Resort Hotel            0         14               2015
# ...              ...          ...        ...                ...
# 119385    City Hotel            0         23               2017
# 119386    City Hotel            0        102               2017
# 119387    City Hotel            0         34               2017
# 119388    City Hotel            0        109               2017
# 119389    City Hotel            0        205               2017
#
#        arrival_date_month  arrival_date_week_number  \
# 0                    July                        27
# 1                    July                        27
# ...

# %% [markdown]
# DATASET LINK

# %% [markdown]
# https://drive.google.com/file/d/1C9AxF9fcVzMw0Bgs0NaRrNML2WwX1Ehm/view

# %% [markdown]
# ### Dataset Rows & Columns count

# %%
# Dataset Rows & Columns count

rows, columns = df.shape
print(f"The dataset has {rows} rows and {columns} columns.")
# Out:
# The dataset has 119390 rows and 32 columns.

# %% [markdown]
# ### Dataset Information

# %%
# Dataset Info
print("\nDataset information:")
print(df.info())
# Out:
# Dataset information:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 119390 entries, 0 to 119389
# Data columns (total 32 columns):
#  #   Column                          Non-Null Count   Dtype
# ---  ------                          --------------   -----
#  0   hotel                           119390 non-null  object
#  1   is_canceled                     119390 non-null  int64
#  2   lead_time                       119390 non-null  int64
#  3   arrival_date_year               119390 non-null  int64
#  4   arrival_date_month              119390 non-null  object
#  5   arrival_date_week_number        119390 non-null  int64
#  6   arrival_date_day_of_month       119390 non-null  int64
#  7   stays_in_weekend_nights         119390 non-null  int64
#  8   stays_in_week_nights            119390 non-null  int64
#  9   adults                          119390 non-null  int64
#  10  children                        119386 non-null  float64
# ...

# %% [markdown]
# #### Duplicate Values

# %%
# Dataset Duplicate Value Count
duplicate_count = df.duplicated().sum()

# Display the count of duplicate rows
print(f"There are {duplicate_count} duplicate rows in the dataset.")
# Out:
# There are 31994 duplicate rows in the dataset.

# %% [markdown]
# #### Missing Values/Null Values

# %%
# Missing Values/Null Values Count
# Display the count of missing values in each column
missing_values = df.isnull().sum()

# Display columns with missing values and their counts
missing_values = missing_values[missing_values > 0]
if not missing_values.empty:
    print("Columns with missing values:")
    print(missing_values)
else:
    print("No missing values in the dataset.")
# Out:
# Columns with missing values:
# children         4
# country        488
# agent        16340
# company     112593
# dtype: int64

# %% [markdown]
# ### What did you know about your dataset?

# %% [markdown]
# After all the above case study on dataset I come across a solution that there are 119390 rows and 32 columns in the dataset with 31994 duplicate rows in it . There are also some columns with missing values in it ; The columns are - Company having 112593 no. of missings values , Agent with 16340 no. of missing values , Country with 488 no. of missing values and Children with 4 no. of missing values .

# %% [markdown]
# ## ***2. Understanding Your Variables***

# %%
# Dataset Columns
df_column= df.columns
print(df_column)
# Out:
# Index(['hotel', 'is_canceled', 'lead_time', 'arrival_date_year',
#        'arrival_date_month', 'arrival_date_week_number',
#        'arrival_date_day_of_month', 'stays_in_weekend_nights',
#        'stays_in_week_nights', 'adults', 'children', 'babies', 'meal',
#        'country', 'market_segment', 'distribution_channel',
#        'is_repeated_guest', 'previous_cancellations',
#        'previous_bookings_not_canceled', 'reserved_room_type',
#        'assigned_room_type', 'booking_changes', 'deposit_type', 'agent',
#        'company', 'days_in_waiting_list', 'customer_type', 'adr',
#        'required_car_parking_spaces', 'total_of_special_requests',
#        'reservation_status', 'reservation_status_date'],
#       dtype='object')

# %%
# Dataset Describe
# Display summary statistics of the numeric columns
df.describe()
# Out:
#          is_canceled      lead_time  arrival_date_year  \
# count  119390.000000  119390.000000      119390.000000
# mean        0.370416     104.011416        2016.156554
# std         0.482918     106.863097           0.707476
# min         0.000000       0.000000        2015.000000
# 25%         0.000000      18.000000        2016.000000
# 50%         0.000000      69.000000        2016.000000
# 75%         1.000000     160.000000        2017.000000
# max         1.000000     737.000000        2017.000000
#
#        arrival_date_week_number  arrival_date_day_of_month  \
# count             119390.000000              119390.000000
# mean                  27.165173                  15.798241
# std                   13.605138                   8.780829
# min                    1.000000                   1.000000
# 25%                   16.000000                   8.000000
# 50%                   28.000000                  16.000000
# ...

# %% [markdown]
# ### Variables Description

# %% [markdown]
# ![hotel_analysis_1_a60b375461.jpg](data:image/jpeg;base64,...)![hotel_analysis_2_398f3b14ea.jpg](data:image/jpeg;base64,...)

# %% [markdown]
# # **Data Cleaning**

# %% [markdown]
# ### Check Unique Values for each variable.

# %%
# Check Unique Values for each variable.
for column in df.columns:
    unique_values = df[column].unique()
    print(f"Unique values for {column}:\n{unique_values}\n")
# Out:
# Unique values for hotel:
# ['Resort Hotel' 'City Hotel']
#
# Unique values for is_canceled:
# [0 1]
#
# Unique values for lead_time:
# [342 737   7  13  14   0   9  85  75  23  35  68  18  37  12  72 127  78
#   48  60  77  99 118  95  96  69  45  40  15  36  43  70  16 107  47 113
#   90  50  93  76   3   1  10   5  17  51  71  63  62 101   2  81 368 364
#  324  79  21 109 102   4  98  92  26  73 115  86  52  29  30  33  32   8
#  100  44  80  97  64  39  34  27  82  94 110 111  84  66 104  28 258 112
#   65  67  55  88  54 292  83 105 280 394  24 103 366 249  22  91  11 108
#  106  31  87  41 304 117  59  53  58 116  42 321  38  56  49 317   6  57
#   19  25 315 123  46  89  61 312 299 130  74 298 119  20 286 136 129 124
#  327 131 460 140 114 139 122 137 126 120 128 135 150 143 151 132 125 157
#  147 138 156 164 346 159 160 161 333 381 149 154 297 163 314 155 323 340
#  356 142 328 144 336 248 302 175 344 382 146 170 166 338 167 310 148 165
# ...

# %%
# Write your code to make your dataset analysis ready.

# lets check, which column has null values
missing_values[:5]
# Out:
# children         4
# country        488
# agent        16340
# company     112593
# dtype: int64

# %%
# drop column with maximum no. of missing values
df.drop(['company'], axis=1, inplace=True)

# %%
# As we can see there is minimal missing values in 'agent' column so replace it with 0
df['agent'].fillna(value = 0, inplace = True)
df['agent'].isnull().sum()
# Out:
# 0

# %%
# as there is less null values in 'country' so replace the null with'other' as country name
df['country'].fillna(value = 'others', inplace = True)
df['country'].isnull().sum()
# Out:
# 0

# %%
# check whether the dataset having any other null value
df.isnull().sum()
# Out:
# hotel                             0
# is_canceled                       0
# lead_time                         0
# arrival_date_year                 0
# arrival_date_month                0
# arrival_date_week_number          0
# arrival_date_day_of_month         0
# stays_in_weekend_nights           0
# stays_in_week_nights              0
# adults                            0
# children                          4
# babies                            0
# meal                              0
# country                           0
# market_segment                    0
# distribution_channel              0
# is_repeated_guest                 0
# previous_cancellations            0
# previous_bookings_not_canceled    0
# reserved_room_type                0
# assigned_room_type                0
# booking_changes                   0
# deposit_type                      0
# agent                             0
# days_in_waiting_list              0
# customer_type                     0
# ...

# %% [markdown]
# ## **Data Transformation**

# %%
# total stay in nights
df['total_stay_in_nights'] = df['stays_in_week_nights'] + df['stays_in_weekend_nights']
df['total_stay_in_nights']
# Out:
# 0         0
# 1         0
# 2         1
# 3         1
# 4         2
#          ..
# 119385    7
# 119386    7
# 119387    7
# 119388    7
# 119389    9
# Name: total_stay_in_nights, Length: 119390, dtype: int64

# %%
# Creat a new column 'revenue'
df['revenue'] = df['total_stay_in_nights'] * df['adr']
df['revenue']
# Out:
# 0            0.00
# 1            0.00
# 2           75.00
# 3           75.00
# 4          196.00
#            ...
# 119385     672.98
# 119386    1578.01
# 119387    1103.97
# 119388     730.80
# 119389    1360.80
# Name: revenue, Length: 119390, dtype: float64

# %%
# for better understanding of 'is_canceled' col replace the value from (0,1) to 'not_canceled' , 'canceled'
df['is_canceled'] = df['is_canceled'].replace([0,1], ['not_canceled', 'canceled'])
df['is_canceled']
# Out:
# 0         not_canceled
# 1         not_canceled
# 2         not_canceled
# 3         not_canceled
# 4         not_canceled
#               ...
# 119385    not_canceled
# 119386    not_canceled
# 119387    not_canceled
# 119388    not_canceled
# 119389    not_canceled
# Name: is_canceled, Length: 119390, dtype: object

# %%
# same as above for 'is_repeated_guest'
df['is_repeated_guest'] = df['is_repeated_guest'].replace([0,1] , ['not_repeated', 'repeated'])
df['is_repeated_guest']
# Out:
# 0         not_repeated
# 1         not_repeated
# 2         not_repeated
# 3         not_repeated
# 4         not_repeated
#               ...
# 119385    not_repeated
# 119386    not_repeated
# 119387    not_repeated
# 119388    not_repeated
# 119389    not_repeated
# Name: is_repeated_guest, Length: 119390, dtype: object

# %%
# Display the first few rows of the cleaned & transformed dataset
print("First few rows of the cleaned dataset:")
print(df.head())
# Out:
# First few rows of the cleaned dataset:
#           hotel   is_canceled  lead_time  arrival_date_year  \
# 0  Resort Hotel  not_canceled        342               2015
# 1  Resort Hotel  not_canceled        737               2015
# 2  Resort Hotel  not_canceled          7               2015
# 3  Resort Hotel  not_canceled         13               2015
# 4  Resort Hotel  not_canceled         14               2015
#
#   arrival_date_month  arrival_date_week_number  arrival_date_day_of_month  \
# 0               July                        27                          1
# 1               July                        27                          1
# 2               July                        27                          1
# 3               July                        27                          1
# 4               July                        27                          1
#
#    stays_in_weekend_nights  stays_in_week_nights  adults  ...  agent  \
# ...

# %% [markdown]
# # **Data Cleaning & Transformation By Tableau Prep**

# %% [markdown]
# #![Screenshot (168).png](data:image/png;base64,...)

# %% [markdown]
# # **Tableau Dashboard:- Hotel Booking Analysis**![HOTEL BOOKING ANALYSIS.png](data:image/png;base64,...)

# %% [markdown]
# # **Conclusion From the Dashboard**

# %% [markdown]
# **1.**  Monthly booking trends is also showing the most no. of bookings in city and resort hotel are higher from may to september and most no. of bookings are in august.
#
# **2.** BB meal is the most preferred food among all in both tpe of hotel.
#
# **3.** Total revenue generated by city hotel is comparatively higher than resort hotel.
#
# **4.** Bubble chart shows that the most no. of bookings come from Online TA(Tour Agent) market segment.
#
# **5.** Total no. of bookings from City hotel is 236,192 and the total no. of bookings from Resort hotel is 171764.
#
# **6.** No. of canceled bookings in City hotel is 33080 and that of Resort hotel is 11077.
#
# **7.** We can also conclude that the no. of repeated guests are more in city hotel as compare to resort hotel.
#
# **8.** Line chart shows the trends in the no. of bookings in week nights vs weekend nights over the years and from that we can eaisly conclude that 2016 is the most profitable year.
#
# **9.** Average Daily Rate(ADR), i.e. average renenue earned according to the occupancy of rooms is much more higher in City hotel as compared to Resort hotel.
#
# **10.** Geographical map shows the guests from the respective country.
